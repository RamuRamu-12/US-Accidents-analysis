# %% [markdown]
# # US Accident Exploratory Data Analysis
#
# ### first talk  about the dataset.
#
#   - info about the accidents
#
#   - useful for the prevention of the accidents
#   - this does not contain the info about the newyork

# %%
import pandas as pd

# %%
data=pd.read_csv("/content/drive/MyDrive/Alpha/Us accidents project/US_Accidents_Dec21_updated.csv")

# %%
data.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08  40.108910
# 1  A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20  39.865420
# 2  A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39  39.102660
# 3  A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45  41.062130
# 4  A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43  39.172393
#
#    Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 0 -83.092860  40.112060 -83.031870         3.230
# 1 -84.062800  39.865010 -84.048730         0.747
# 2 -84.524680  39.102090 -84.523960         0.055
# 3 -81.537840  41.062170 -81.535470         0.123
# 4 -84.492792  39.170476 -84.501798         0.500
#
#                                          Description  ...  Roundabout Station  \
# 0  Between Sawmill Rd/Exit 20 and OH-315/Olentang...  ...       False   False
# 1                 At OH-4/OH-235/Exit 41 - Accident.  ...       False   False
# ...

# %%
data.shape
# Out:
# (2845342, 47)

# %% [markdown]
# ## Data Preparation and Cleaning
#
#    - info about the dataset
#    - finding any missing values and fix it

# %%
data.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845342 entries, 0 to 2845341
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %%
data.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06
# mean   2.137572e+00  3.624520e+01 -9.711463e+01  3.624532e+01 -9.711439e+01
# std    4.787216e-01  5.363797e+00  1.831782e+01  5.363873e+00  1.831763e+01
# min    1.000000e+00  2.456603e+01 -1.245481e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.344517e+01 -1.180331e+02  3.344628e+01 -1.180333e+02
# 50%    2.000000e+00  3.609861e+01 -9.241808e+01  3.609799e+01 -9.241772e+01
# 75%    2.000000e+00  4.016024e+01 -8.037243e+01  4.016105e+01 -8.037338e+01
# max    4.000000e+00  4.900058e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)        Number  Temperature(F)  Wind_Chill(F)  \
# count  2.845342e+06  1.101431e+06    2.776068e+06   2.375699e+06
# mean   7.026779e-01  8.089408e+03    6.179356e+01   5.965823e+01
# std    1.560361e+00  1.836009e+04    1.862263e+01   2.116097e+01
# ...

# %%
## checking the number of the numerical columns in the dataset.
numerics=["int16","int32","int64","float16","float32","float64"]
numeric_df=data.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 14

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# Number                   1743911
# Precipitation(in)         549458
# Wind_Chill(F)             469643
# Wind_Speed(mph)           157944
# Wind_Direction             73775
# Humidity(%)                73092
# Weather_Condition          70636
# Visibility(mi)             70546
# Temperature(F)             69274
# Pressure(in)               59200
# Weather_Timestamp          50736
# Airport_Code                9549
# Timezone                    3659
# Nautical_Twilight           2867
# Civil_Twilight              2867
# Sunrise_Sunset              2867
# Astronomical_Twilight       2867
# Zipcode                     1319
# City                         137
# Street                         2
# Country                        0
# Junction                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Turning_Loop                   0
# Traffic_Signal                 0
# Traffic_Calming                0
# ...

# %%
## Percentage of missing values including zeros
miss=data.isnull().sum().sort_values(ascending=False)/len(data)
miss
# Out:
# Number                   6.129003e-01
# Precipitation(in)        1.931079e-01
# Wind_Chill(F)            1.650568e-01
# Wind_Speed(mph)          5.550967e-02
# Wind_Direction           2.592834e-02
# Humidity(%)              2.568830e-02
# Weather_Condition        2.482514e-02
# Visibility(mi)           2.479350e-02
# Temperature(F)           2.434646e-02
# Pressure(in)             2.080593e-02
# Weather_Timestamp        1.783125e-02
# Airport_Code             3.356011e-03
# Timezone                 1.285961e-03
# Nautical_Twilight        1.007612e-03
# Civil_Twilight           1.007612e-03
# Sunrise_Sunset           1.007612e-03
# Astronomical_Twilight    1.007612e-03
# Zipcode                  4.635647e-04
# City                     4.814887e-05
# Street                   7.029032e-07
# Country                  0.000000e+00
# Junction                 0.000000e+00
# Start_Time               0.000000e+00
# End_Time                 0.000000e+00
# Start_Lat                0.000000e+00
# ...

# %%
## Missing values  percentages without zeroes
miss1=miss[miss!=0]
miss1
# Out:
# Number                   6.129003e-01
# Precipitation(in)        1.931079e-01
# Wind_Chill(F)            1.650568e-01
# Wind_Speed(mph)          5.550967e-02
# Wind_Direction           2.592834e-02
# Humidity(%)              2.568830e-02
# Weather_Condition        2.482514e-02
# Visibility(mi)           2.479350e-02
# Temperature(F)           2.434646e-02
# Pressure(in)             2.080593e-02
# Weather_Timestamp        1.783125e-02
# Airport_Code             3.356011e-03
# Timezone                 1.285961e-03
# Nautical_Twilight        1.007612e-03
# Civil_Twilight           1.007612e-03
# Sunrise_Sunset           1.007612e-03
# Astronomical_Twilight    1.007612e-03
# Zipcode                  4.635647e-04
# City                     4.814887e-05
# Street                   7.029032e-07
# dtype: float64

# %%
miss1.plot(kind="barh")
# Out:
# <Axes: >

# %% [markdown]
# # Exploratory Analysis and Visualisation
#
#  Columns should be considered:
#
#  1.City
#
#  2.Start time
#
#  3.Start lat,Start lng

# %%
data.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
#Finding the number of cities in the accidents
cities =data.City.unique()

# %%
len(cities)
# Out:
# 11682

# %%
cities
# Out:
# array(['Dublin', 'Dayton', 'Cincinnati', ..., 'Clarksdale', 'Bridgeboro',
#        'American Fork-Pleasant Grove'], dtype=object)

# %%
#number of accidents occured in a single city as per the datasets
accident_count=data.City.value_counts()

# %%
accident_count
# Out:
# Miami                           106966
# Los Angeles                      68956
# Orlando                          54691
# Dallas                           41979
# Houston                          39448
#                                  ...
# Ridgedale                            1
# Sekiu                                1
# Wooldridge                           1
# Bullock                              1
# American Fork-Pleasant Grove         1
# Name: City, Length: 11681, dtype: int64

# %%
accident_count[:10]
# Out:
# Miami          106966
# Los Angeles     68956
# Orlando         54691
# Dallas          41979
# Houston         39448
# Charlotte       33152
# Sacramento      32559
# San Diego       26627
# Raleigh         22840
# Minneapolis     22768
# Name: City, dtype: int64

# %%
accident_count[:15].plot(kind="barh")
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.set_style("darkgrid")

# %%
high_accident_cities=accident_count[accident_count>=1000]

low_accident_cities=accident_count[accident_count<1000]

# %%
len(high_accident_cities)
# Out:
# 496

# %%
len(low_accident_cities)
# Out:
# 11185

# %%
sns.distplot(high_accident_cities)
# Out:
# <ipython-input-27-50976d58a416>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(high_accident_cities)
# <Axes: xlabel='City', ylabel='Density'>

# %%
## Percentage of the cities with high accidents
len(high_accident_cities)/len(cities)*100
# Out:
# 4.245848313644924

# %%
sns.histplot(accident_count,log_scale=True)
# Out:
# <Axes: xlabel='City', ylabel='Count'>

# %% [markdown]
# ## Start Time

# %%
data.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
data.Start_Time[0]
# Out:
# '2016-02-08 00:37:08'

# %%
data.Start_Time=pd.to_datetime(data.Start_Time)

# %%
data.Start_Time[0]
# Out:
# Timestamp('2016-02-08 00:37:08')

# %%
## getting the hour at which the accident may done
accident_hour=data.Start_Time.dt.hour

# %%
accident_hour
# Out:
# 0           0
# 1           5
# 2           6
# 3           6
# 4           7
#            ..
# 2845337    18
# 2845338    19
# 2845339    19
# 2845340    19
# 2845341    18
# Name: Start_Time, Length: 2845342, dtype: int64

# %%
#Plot describes the number of accidents done on each hour in a day.
sns.histplot(accident_hour,bins=24,stat="density")
# Out:
# <Axes: xlabel='Start_Time', ylabel='Density'>

# %%
# Plot shows the  accidents on the particular day
sns.histplot(data.Start_Time.dt.day_of_week,bins=24)
# Out:
# <Axes: xlabel='Start_Time', ylabel='Count'>

# %%
# To plot the accidnents on each hour on the particular day i.e Sunday.
sunday_start_time=data.Start_Time[data.Start_Time.dt.dayofweek==0]
sns.histplot(sunday_start_time.dt.hour,bins=24)
# Out:
# <Axes: xlabel='Start_Time', ylabel='Count'>

# %%
# To plot the accidnents on each hour on the particular day i.e Friday.
friday_start_time=data.Start_Time[data.Start_Time.dt.dayofweek==5]
sns.histplot(friday_start_time.dt.hour,bins=24)
# Out:
# <Axes: xlabel='Start_Time', ylabel='Count'>

# %%
#Accidents graph per month
sns.histplot(data.Start_Time.dt.month,bins=12)
# Out:
# <Axes: xlabel='Start_Time', ylabel='Count'>

# %%
#Accidents graph per year
sns.histplot(data.Start_Time.dt.year,stat="percent")
# Out:
# <Axes: xlabel='Start_Time', ylabel='Percent'>

# %%
## Accidents done in a particular year month wise.
df_2019=data[data.Start_Time.dt.year==2019]
sns.histplot(df_2019.Start_Time.dt.month,bins=12)
# Out:
# <Axes: xlabel='Start_Time', ylabel='Count'>

# %% [markdown]
# ## Start_lattitude & Start_longitude

# %%
data.Start_Lat
# Out:
# 0          40.108910
# 1          39.865420
# 2          39.102660
# 3          41.062130
# 4          39.172393
#              ...
# 2845337    34.002480
# 2845338    32.766960
# 2845339    33.775450
# 2845340    33.992460
# 2845341    34.133930
# Name: Start_Lat, Length: 2845342, dtype: float64

# %%
data.Start_Lng
# Out:
# 0          -83.092860
# 1          -84.062800
# 2          -84.524680
# 3          -81.537840
# 4          -84.492792
#               ...
# 2845337   -117.379360
# 2845338   -117.148060
# 2845339   -117.847790
# 2845340   -118.403020
# 2845341   -117.230920
# Name: Start_Lng, Length: 2845342, dtype: float64

# %%
sample_df=data.sample(int(0.05*len(data)))

# %%
sns.scatterplot(x=sample_df.Start_Lng,y=sample_df.Start_Lat,marker="*")
# Out:
# <Axes: xlabel='Start_Lng', ylabel='Start_Lat'>

# %%
import folium

# %%
lat,lon=data.Start_Lat[0],data.Start_Lng[0]

# %%
map=folium.Map()
marker=folium.Marker((lat,lon))
marker.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from folium.plugins import HeatMap

# %%
sample_df=data.sample(int(0.01*len(data)))
locations = sample_df[['Start_Lat', 'Start_Lng']]
locationlist = locations.values.tolist()

# %%
map=folium.Map()
HeatMap(locationlist).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## Analysis of the project
#
# It consists of the several points to conclude,
#
#  - The data consists of the all types of the data including in it.Ex:bool,object etc.
#  - As per the count of the acccidents in cities,Miami has the highest number of accidents(106966 accidents)
#  -There are 496 cities which are having high number of accidents.(4.24% of whole data).
#  -There are 11185 cities which are having low number of accidents.
#  -There are some cities having the only one accident also.
#  - The most number of cities which comes under the average number of accidents case.
#  - The maximum number of accidents can be occured from the time range of 3:00PM to 6:00PM.in a day
#  -In a week, the accidents occurance should be increasing from the monday to th e thursday and then decreasing quietly in remaining days.
#  -Accidents should not be done mostly on weekends.
#  - As we observe the seasons of occuring the accidents,Winter seasons would come in to the first place as the count of the accidents should be high
#  - The occurance of the accidents should be increasing from an year to the year and having the maximum count in 2021.
